# %% [markdown]
# <a href="https://colab.research.google.com/github/fralfaro/MAT281_2022/blob/main/labs/lab_04/lab_04.ipynb
# " target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # MAT281 - Laboratorio N°04

# %% [markdown]
# ## Problema 01
#
# <img src="http://nelsoncos.com/wp-content/uploads/2017/02/sales-icon.png" width="360" height="360" align="center"/>
#
#
# EL conjunto de datos se denomina `company_sales_data.csv`, el cual contiene información tal como: número del mes, unidades, precio, etc.
#
# Lo primero es cargar el conjunto de datos y ver las primeras filas que lo componen:

# %%
#libreria

import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(rc={'figure.figsize':(10,8)})

# %%
# cargar datos
df = pd.read_csv("https://raw.githubusercontent.com/fralfaro/MAT281_2022/main/labs/lab_04/data/company_sales_data.csv")
df.head()
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
# 1             2       2630      1200        5100         6100     2100
# 2             3       2140      1340        4550         9550     3550
# 3             4       3400      1130        5870         8870     1870
# 4             5       3600      1740        4560         7760     1560
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000
# 1         1200        18330        183300
# 2         1340        22470        224700
# 3         1130        22270        222700
# 4         1740        20960        209600

# %% [markdown]
# El objetivo es tratar de obtener la mayor información posible de este conjunto de datos. Para cumplir este objetivo debe resolver las siguientes problemáticas:
#
# **Observación.-** Puedes ocupar las librerías de Matplolib o Seaborn.

# %% [markdown]
# 1. Lea el "total_profit" de todos los meses, muéstrelo usando un gráfico lineal y un gráfico de dispersión.

# %%
eje_x = df['month_number'] #eje x
eje_y = df['total_profit'] #eje y
 
plt.plot(eje_x, eje_y) #gráfico
plt.title('Beneficio Total v/s Mes') #título
plt.xlabel('Mes') 
plt.ylabel('Beneficio Total') 
plt.show() #mostramos el gráfico

# %%
data={'profit': eje_x, 'month': eje_y} #creamos el eje x e y

dfa= pd.DataFrame(data = data); #creamos un DataFrame
dfa.plot.scatter(x = 'profit', y = 'month', s = 50, c='blue'); #gráfico de dispersión
plt.title('Beneficio Total vs Mes') #nombre del gráfico
plt.xlabel('Mes') 
plt.ylabel('Beneficio Total') 
plt.show() #mostramos el gráfico

# %% [markdown]
# 2. Lea todos los datos de ventas de productos y muéstrelos utilizando un gráfico multilínea.

# %%
for col in df.columns: #Leemos cada columna
    if not col == 'month_number' and not col == 'total_profit' and not col =='total_units': #ponemos condiciones para no leer total units ni total profit
        plt.plot(df['month_number'], df[col], label=col) #plot

plt.legend() #leyenda de los productos
plt.title('Ventas según producto') #nombre del gráfico
plt.xlabel('Mes') 
plt.ylabel('Ventas') 
plt.show() #mostramos el gráfico

# %% [markdown]
# 3. Lea los datos de ventas de productos de "facecream" y "facewash" y muéstrelos usando el gráfico de barras.

# %%
df[['facecream', 'facewash']].plot.bar() #Se grafican las barras que tangan de nombre 'facecream' y 'facewash' (nombre de las columnas del df)
plt.title('Ventas según producto por mes') #nombre del gráfico
plt.xlabel('Mes') 
plt.ylabel('Ventas') 
plt.show() #mostramos el gráfico

# %% [markdown]
# 4. Lea todos los datos de ventas de productos y muéstrelos utilizando un gráfico box-plot.

# %%
df1=df.drop(['month_number','total_units','total_profit'], axis=1) #dataframe con atributos necesarios
df1.plot(kind='box') #grafico de caja
plt.title('Ventas según producto') #nombre del gráfico
plt.xlabel('Producto') 
plt.ylabel('Ventas') 
plt.show() #mostramos el gráfico, se notan outliers.

# %% [markdown]
# 5. Calcule los datos de ventas totales del año pasado para cada producto y muéstrelos usando un gráfico circular

# %%
J=df1[df1.columns[0:]].sum() #suma de productos durante el año pasado
plt.pie(J, labels=df1.columns, autopct='%1.1f%%') #porcentaje de venta de cada producto
plt.title('Ventas totales del año pasado por producto') #Título del gráfico 
plt.show() #mostramos el gráfico circular
